# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

images = np.load("D:/work/JHUschoolStuff/machinelearning/project1/cs475_project_data/images.npy")
labels = np.load("D:/work/JHUschoolStuff/machinelearning/project1/cs475_project_data/labels.npy")

class_0_images = images[labels == 0]
plt.imshow(class_0_images[0])
plt.set_cmap("gray")

# %%
class_1_images = images[labels == 1]
plt.imshow(class_1_images[0])
plt.set_cmap("gray")

# %%
class_2_images = images[labels == 2]
plt.imshow(class_2_images[0])
plt.set_cmap("gray")

# %%
class_3_images = images[labels == 3]
plt.imshow(class_3_images[0])
plt.set_cmap("gray")

# %%
class_4_images = images[labels == 4]
plt.imshow(class_4_images[0])
plt.set_cmap("gray")

# %% [markdown]
# The apple class is associated with 0.
# The baseball class is associated with 1.
# The clock class is associated with 3.
# The cookie class is associated with 2.
# The fan class is associated with 4.

# %%
height = images.shape[1]
width = images.shape[2]
size = height*width
images = images.reshape(images.shape[0],size)
print(images.shape)
# Out:
# (50000, 676)

# %%
for i in range(0, 5):
    plt.plot(images[i], '-b')
plt.show()
